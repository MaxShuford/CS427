# %%
import pandas as pd
import numpy as np
import glob
import matplotlib.pyplot as plt

# %%
glob.glob('*.csv')
# Out:
# ['New_books.csv']

# %% [markdown]
# ## Load data

# %%
cleaned_books_df = pd.read_csv('New_books.csv')
cleaned_books_df.head()
# Out:
#   Place of Publication Date of Publication              Publisher  \
# 0               London               1879        S. Tinsley & Co.
# 1               London                1868           Virtue & Co.
# 2               London                1869  Bradbury, Evans & Co.
# 3               London                1851          James Darling
# 4               London                1857   Wertheim & Macintosh
#
#                                                Title    Author  \
# 0                                      Walter Forbes        AA
# 1                                      All For Greed   A. A A.
# 2                                   Love The Avenger   A. A A.
# 3  Welsh Sketches, Chiefly Ecclesiastical, To The...   E. S A.
# 4      The World In Which I Live, And My Place In It   E. S A.
#
#                                           Flickr URL
# 0  http://www.flickr.com/photos/britishlibrary/ta...
# 1  http://www.flickr.com/photos/britishlibrary/ta...
# 2  http://www.flickr.com/photos/britishlibrary/ta...
# 3  http://www.flickr.com/photos/britishlibrary/ta...
# 4  http://www.flickr.com/photos/britishlibrary/ta...

# %%
cleaned_books_df.describe()
# Out:
#        Place of Publication Date of Publication        Publisher  Title  \
# count                  8287                7320             4092   8274
# unique                 1192                 403             1989   8031
# top                  London                1897  Macmillan & Co.  Poems
# freq                   4219                 174               85     10
#
#                       Author  \
# count                   6509
# unique                  4949
# top      William Shakespeare
# freq                      48
#
#                                                Flickr URL
# count                                                8287
# unique                                               8287
# top     http://www.flickr.com/photos/britishlibrary/ta...
# freq                                                    1

# %% [markdown]
# ## 1. Get the top 5 publishers and their published number.
# To understanding Market Dynamics, identifying the top publishers helps understand the publishing market's dynamics during a specific period. It can indicate which publishers were dominant and how the publishing landscape might have been shaped by their activities.

# %%
cleaned_books_df['Publisher'].value_counts()
# Out:
# Publisher
# Macmillan & Co.      85
# London               69
# Privately printed    53
# Longmans & Co.       52
# Hurst & Blackett     51
#                      ..
# F. Murray             1
# J. Davidson & Co.     1
# Punch Office          1
# J. Cooke, etc.        1
# W. Abbatt             1
# Name: count, Length: 1989, dtype: int64

# %%
n = 5
publisher_list = cleaned_books_df['Publisher'].value_counts()[:n]
publisher_list
# Out:
# Publisher
# Macmillan & Co.      85
# London               69
# Privately printed    53
# Longmans & Co.       52
# Hurst & Blackett     51
# Name: count, dtype: int64

# %%
publisher_list.index, publisher_list.to_list()
# Out:
# (Index(['Macmillan & Co.', 'London', 'Privately printed', 'Longmans & Co.',
#         'Hurst & Blackett'],
#        dtype='object', name='Publisher'),
#  [85, 69, 53, 52, 51])

# %%
plt.bar(publisher_list.index,publisher_list.to_list())
# Out:
# <BarContainer object of 5 artists>

# %%
# Creating a bar graph
plt.figure(figsize=(8,6))

#load your data
#Your code:
x_list = publisher_list.index
y_list = publisher_list.to_list()
plt.bar(x_list, y_list, width=0.2, color='red', align='center', label = 'Top 5 - Publishers')

# Annotating each bar with the corresponding most publish number of items
# Your Code:
for i in range(len(y_list)):
    value = y_list[i]
    plt.text(i, value, str(value)+"+", ha ='center', va='bottom')
    
plt.legend()
plt.title('Get the top 5 publishers and their published number.',fontsize=18)
plt.xlabel('Publisher',fontsize=17)
plt.ylabel('Number of Published Items',fontsize=16)
plt.grid(axis='y')

plt.show()

# %% [markdown]
# ## Practice 1
# ### 1.1 Identify the top five publishers with the greatest number of books published.
# ### 1.2 Ascertain the year in which each of these publishers achieved their highest sales, along with the total number of books they published in that particular year.

# %%
publisher_list
# Out:
# Publisher
# Macmillan & Co.      85
# London               69
# Privately printed    53
# Longmans & Co.       52
# Hurst & Blackett     51
# Name: count, dtype: int64

# %%
# Selecting the data for the chosen publisher "Macmillan & Co."
macdf = cleaned_books_df[cleaned_books_df['Publisher'] == 'Macmillan & Co.']
macdf['Date of Publication'].value_counts()[:1]
macdf
# Out:
#      Place of Publication Date of Publication        Publisher  \
# 102                London                1886  Macmillan & Co.
# 210                London                1876  Macmillan & Co.
# 239                London                1887  Macmillan & Co.
# 306                London                1886  Macmillan & Co.
# 352                London                1896  Macmillan & Co.
# ...                   ...                 ...              ...
# 7492               London                1884  Macmillan & Co.
# 7536               London                1888  Macmillan & Co.
# 7577               London                1884  Macmillan & Co.
# 8175            Cambridge                1857  Macmillan & Co.
# 8205               London                1893  Macmillan & Co.
#
#                                                   Title  \
# 102   The Cruise Of Her Majesty's Ship “bacchante,” ...
# 210   Mandalay To Momien: A Narrative Of The Two Exp...
# 239                         The New Antigone. A Romance
# 306                       King Arthur. Not A Love Story
# 352                                    Emma. New Editio
# ...                                                 ...
# 7492                    Miss Tommy. A Mediaeval Romance
# 7536  Coaching Days And Coaching Ways ... With Illus...
# 7577  Samoa A Hundred Years Ago And Long Before, Tog...
# 8175        A Long Vacation Ramble In Norway And Sweden
# 8205            Strolling Players. A Harmony Of Contras
#
#                         Author  \
# 102                        NaN
# 210             John  Anderson
# 239                        NaN
# 306                        NaN
# 352                Jane Austen
# ...                        ...
# 7492                       NaN
# 7536   William Outram Tristram
# 7577            George  Turner
# 8175                       NaN
# 8205      Charlotte Mary Yonge
#
#                                              Flickr URL
# 102   http://www.flickr.com/photos/britishlibrary/ta...
# 210   http://www.flickr.com/photos/britishlibrary/ta...
# 239   http://www.flickr.com/photos/britishlibrary/ta...
# 306   http://www.flickr.com/photos/britishlibrary/ta...
# 352   http://www.flickr.com/photos/britishlibrary/ta...
# ...                                                 ...
# 7492  http://www.flickr.com/photos/britishlibrary/ta...
# 7536  http://www.flickr.com/photos/britishlibrary/ta...
# 7577  http://www.flickr.com/photos/britishlibrary/ta...
# 8175  http://www.flickr.com/photos/britishlibrary/ta...
# 8205  http://www.flickr.com/photos/britishlibrary/ta...
#
# [85 rows x 6 columns]

# %%
d = {}
for pub in publisher_list.index:
    print(pub)
    auth_cleaned_books = cleaned_books_df[cleaned_books_df['Publisher'] == pub]
    year_info = auth_cleaned_books['Date of Publication'].value_counts()[:1]
    year = year_info.index[0]
    bookNum = year_info[0]
    d[pub] = [year, bookNum]

d
# Out:
# Macmillan & Co.
# London
# Privately printed
# Longmans & Co.
# Hurst & Blackett
# C:\Users\MaxSh\AppData\Local\Temp\ipykernel_9464\790959946.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   bookNum = year_info[0]
# C:\Users\MaxSh\AppData\Local\Temp\ipykernel_9464\790959946.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   bookNum = year_info[0]
# C:\Users\MaxSh\AppData\Local\Temp\ipykernel_9464\790959946.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   bookNum = year_info[0]
# C:\Users\MaxSh\AppData\Local\Temp\ipykernel_9464\790959946.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   bookNum = year_info[0]
# C:\Users\MaxSh\AppData\Local\Temp\ipykernel_9464\790959946.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   bookNum = year_info[0]
# {'Macmillan & Co.': ['1896', np.int64(16)],
#  'London': ['1866', np.int64(3)],
#  'Privately printed': ['1880', np.int64(3)],
#  'Longmans & Co.': ['1889', np.int64(6)],
#  'Hurst & Blackett': ['1856', np.int64(3)]}

# %%
publisher_name = list(d.keys())
most_pub_year = [d[publisher][0] for publisher in d] 
publish_item = [d[publisher][1] for publisher in d] 
# Creating a bar graph
plt.figure(figsize=(8,6))

#Your code:
x_list = publisher_list.index
y_list = publish_item
plt.bar(x_list, y_list, width=0.2, color='magenta', align='center')

# Annotating each bar with the corresponding most publish number of items
# Your code:
for i in range(len(publish_item)):
    year = most_pub_year[i]
    x_posi = i
    x_posi = publish_item[i]
    text_value = "Year -- " +year
    value = y_list[i]
    plt.text(i, value, text_value, ha ='center', va='bottom')

plt.legend()
plt.title('Publishers and their most published books yearly with sales figures')
plt.xlabel('Publisher', fontsize = 17)
plt.ylabel('NUmber of published books', fontsize = 16)
plt.grid(axis='y')

plt.show()
# Out:
# C:\Users\MaxSh\AppData\Local\Temp\ipykernel_9464\3194388770.py:22: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %% [markdown]
# ## 2. Get the 5 most published place
# Reason: For contemporary publishers, marketers, and authors, understanding historical publishing centers can provide insights into established markets and potential opportunities for new ventures or expansions.

# %%
cleaned_books_df.head()
# Out:
#   Place of Publication Date of Publication              Publisher  \
# 0               London               1879        S. Tinsley & Co.
# 1               London                1868           Virtue & Co.
# 2               London                1869  Bradbury, Evans & Co.
# 3               London                1851          James Darling
# 4               London                1857   Wertheim & Macintosh
#
#                                                Title    Author  \
# 0                                      Walter Forbes        AA
# 1                                      All For Greed   A. A A.
# 2                                   Love The Avenger   A. A A.
# 3  Welsh Sketches, Chiefly Ecclesiastical, To The...   E. S A.
# 4      The World In Which I Live, And My Place In It   E. S A.
#
#                                           Flickr URL
# 0  http://www.flickr.com/photos/britishlibrary/ta...
# 1  http://www.flickr.com/photos/britishlibrary/ta...
# 2  http://www.flickr.com/photos/britishlibrary/ta...
# 3  http://www.flickr.com/photos/britishlibrary/ta...
# 4  http://www.flickr.com/photos/britishlibrary/ta...

# %%
cleaned_books_df.describe()
# Out:
#        Place of Publication Date of Publication        Publisher  Title  \
# count                  8287                7320             4092   8274
# unique                 1192                 403             1989   8031
# top                  London                1897  Macmillan & Co.  Poems
# freq                   4219                 174               85     10
#
#                       Author  \
# count                   6509
# unique                  4949
# top      William Shakespeare
# freq                      48
#
#                                                Flickr URL
# count                                                8287
# unique                                               8287
# top     http://www.flickr.com/photos/britishlibrary/ta...
# freq                                                    1

# %%
n = 5
publisher_place_list = cleaned_books_df['Place of Publication'].value_counts()[:n]
publisher_place_list
# Out:
# Place of Publication
# London       4219
# Paris         479
# Edinburgh     208
# New York      177
# Leipzig       119
# Name: count, dtype: int64

# %%
other_place_number = int(cleaned_books_df['Place of Publication'].value_counts() [5:].sum())
other_place_number
# Out:
# 3085

# %%
#create publish_place_data
def get_publish_place_data(n,df):
    #n: Number of target searches
    #df: input dataframe
    # Your code:
    publisher_place_list = cleaned_books_df['Place of Publication'].value_counts()[:n]
    other_place_number = int(cleaned_books_df['Place of Publication'].value_counts()[n:].sum())

    d = {}
    for pub, item in zip(publisher_place_list.index, publisher_place_list):
        d[pub] = item
    
    d["Others"] = other_place_number
    return d
    
get_publish_place_data(5,cleaned_books_df)
# Out:
# {'London': 4219,
#  'Paris': 479,
#  'Edinburgh': 208,
#  'New York': 177,
#  'Leipzig': 119,
#  'Others': 3085}

# %%
# Pie Chart Analysis: 

# Sample data provided earlier (assuming the same structure as the actual dataset)
place_of_data = get_publish_place_data(5,cleaned_books_df)

# Extracting data for pie chart
places = list(place_of_data.keys())
publications = [place_of_data[place] for place in places]
print(places)
print(publications)


# Creating a pie chart
plt.figure(figsize = (8,8))
# Your Pie chart code:
plt.pie(publications, labels = places, autopct ='%1.1f%%', startangle=140, textprops={'fontsize':15})

plt.title('Distribution of Publications by Top 5 places', fontsize =20)
plt.show()
# Out:
# ['London', 'Paris', 'Edinburgh', 'New York', 'Leipzig', 'Others']
# [4219, 479, 208, 177, 119, 3085]

# %% [markdown]
# ### 3.1 Demo for  `.groupby`  function

# %%
# Sample DataFrame
df = pd.DataFrame({'Category': ['A', 'B', 'A', 'B'],
                   'Values': [10, 20, 30, 40]})

df
# Out:
#   Category  Values
# 0        A      10
# 1        B      20
# 2        A      30
# 3        B      40

# %%
# Grouping by 'Category' and calculating the size of each group
grouped = df.groupby('Category').size()

print(grouped)
# Out:
# Category
# A    2
# B    2
# dtype: int64

# %%
# Grouping by 'Category' and calculating the mean of each group
grouped = df.groupby('Category').sum()

print(grouped)
# Out:
#           Values
# Category
# A             40
# B             60

# %% [markdown]
# ## 3. Show the yearly trend in the number of publications

# %% [markdown]
# ### 3.2 Use `.groupby` on Books data

# %%
cleaned_books_df.head()
# Out:
#   Place of Publication Date of Publication              Publisher  \
# 0               London               1879        S. Tinsley & Co.
# 1               London                1868           Virtue & Co.
# 2               London                1869  Bradbury, Evans & Co.
# 3               London                1851          James Darling
# 4               London                1857   Wertheim & Macintosh
#
#                                                Title    Author  \
# 0                                      Walter Forbes        AA
# 1                                      All For Greed   A. A A.
# 2                                   Love The Avenger   A. A A.
# 3  Welsh Sketches, Chiefly Ecclesiastical, To The...   E. S A.
# 4      The World In Which I Live, And My Place In It   E. S A.
#
#                                           Flickr URL
# 0  http://www.flickr.com/photos/britishlibrary/ta...
# 1  http://www.flickr.com/photos/britishlibrary/ta...
# 2  http://www.flickr.com/photos/britishlibrary/ta...
# 3  http://www.flickr.com/photos/britishlibrary/ta...
# 4  http://www.flickr.com/photos/britishlibrary/ta...

# %%
cleaned_books_df['Date of Publication']
# Out:
# 0       1879
# 1        1868
# 2        1869
# 3        1851
# 4        1857
#         ...
# 8282     1838
# 8283     1831
# 8284      NaN
# 8285     1834
# 8286     1834
# Name: Date of Publication, Length: 8287, dtype: object

# %%
yearly_publication_counts = cleaned_books_df.groupby('Date of Publication').size()
yearly_publication_counts
# Out:
# Date of Publication
# 112. G. & W. B. Whittaker    1
# 1510?]                       1
# 1540                         1
# 1570                         1
# 1592                         1
#                             ..
# 1900]                        1
# 1911.                        1
# 1915                         1
# MDCCCC.                      1
# c.1825]                      1
# Length: 403, dtype: int64

# %%
for i in yearly_publication_counts.index:
    print(i,type(i))
# Out:
# 1883 <class 'str'>
# 1883  <class 'str'>
# 1884 <class 'str'>
# 1884  <class 'str'>
# 1884] <class 'str'>
# 1885 <class 'str'>
# 1885  <class 'str'>
# 1885.] <class 'str'>
# 1885] <class 'str'>
# 1886 <class 'str'>
# 1886  <class 'str'>
# 1886] <class 'str'>
# 1887 <class 'str'>
# 1887  <class 'str'>
# 1887] <class 'str'>
# 1888 <class 'str'>
# 1888  <class 'str'>
# 1888.] <class 'str'>
# 1888] <class 'str'>
# 1889 <class 'str'>
# 1889  <class 'str'>
# 1889] <class 'str'>
# 1890 <class 'str'>
# 1890  <class 'str'>
# 1890] <class 'str'>
# 1891 <class 'str'>
# 1891  <class 'str'>
# 1891] <class 'str'>
# 1892 <class 'str'>
# 1892  <class 'str'>
# 1892.] <class 'str'>
# 1892] <class 'str'>
# 1893 <class 'str'>
# 1893  <class 'str'>
# 1893] <class 'str'>
# 1894 <class 'str'>
# 1894  <class 'str'>
# 1894.] <class 'str'>
# 1894] <class 'str'>
# 1895 <class 'str'>
# 1895  <class 'str'>
# 1895] <class 'str'>
# 1896 <class 'str'>
# 1896  <class 'str'>
# 1896.] <class 'str'>
# 1896] <class 'str'>
# 1897 <class 'str'>
# 1897  <class 'str'>
# 1898 <class 'str'>
# 1898  <class 'str'>
# 1898?] <class 'str'>
# 1898] <class 'str'>
# 1899 <class 'str'>
# 1899] <class 'str'>
# 1900] <class 'str'>
# 1911.  <class 'str'>
# 1915 <class 'str'>
# MDCCCC.  <class 'str'>
# c.1825] <class 'str'>

# %%
def clean_year(year):
    
    if year == 'nan':
        return '0'
    if year[0]!='1':
        year=year[year.find('1'):]
    if ' ' in year:
        year=year[:year.find(' ')]
    if '/' in year:
        year=year[:year.find('/')]
    if '?' in year:
        year = year[:year.find('?')]
    if ']' in year:
        year = year[:year.find(']')]
    if '.' in year:
        year = year[:year.find('.')]

    if year.isdigit():
        year = int(year)
    else:
        year = 30

    return year

cleaned_books_df['Date of Publication'] = cleaned_books_df['Date of Publication'].astype(str)
cleaned_books_df['Date of Publication'] = cleaned_books_df['Date of Publication'].apply(clean_year)
cleaned_books_df['Date of Publication'] = cleaned_books_df['Date of Publication'].astype(int)
cleaned_books_df.head()
# Out:
#   Place of Publication  Date of Publication              Publisher  \
# 0               London                 1879       S. Tinsley & Co.
# 1               London                 1868           Virtue & Co.
# 2               London                 1869  Bradbury, Evans & Co.
# 3               London                 1851          James Darling
# 4               London                 1857   Wertheim & Macintosh
#
#                                                Title    Author  \
# 0                                      Walter Forbes        AA
# 1                                      All For Greed   A. A A.
# 2                                   Love The Avenger   A. A A.
# 3  Welsh Sketches, Chiefly Ecclesiastical, To The...   E. S A.
# 4      The World In Which I Live, And My Place In It   E. S A.
#
#                                           Flickr URL
# 0  http://www.flickr.com/photos/britishlibrary/ta...
# 1  http://www.flickr.com/photos/britishlibrary/ta...
# 2  http://www.flickr.com/photos/britishlibrary/ta...
# 3  http://www.flickr.com/photos/britishlibrary/ta...
# 4  http://www.flickr.com/photos/britishlibrary/ta...

# %% [markdown]
# ### Get line plot

# %%
# Scatter Plot Analysis: Year of Publication vs. Number of Publications

# Grouping the data by 'Date of Publication' to count the number of publications each year
testdata = cleaned_books_df[cleaned_books_df['Date of Publication']>1000]
yearly_Publication_count = testdata.groupby('Date of Publication').size()

# Sorting the data by year (index of the grouped data)
sorted_years = yearly_Publication_count.sort_index()

# Creating a scatter plot
plt.figure(figsize=(10,6))
plt.scatter(sorted_years.index,sorted_years,color='blue')


plt.title('Year of Publication vs. Number of Publications',fontsize=18)
plt.xlabel('Year of Publication',fontsize=17)
plt.ylabel('Number of publications',fontsize=16)
plt.grid(axis='y')

plt.show()

# A line graph to show the yearly trend in the number of publications.

# %% [markdown]
# ## Practice 2
# ### Identify the top five publishers with their publicated books during 1800 - 1900. (line graph)

# %%
publish_list = cleaned_books_df['Publisher'].value_counts()[:5]
publish_list
# Out:
# Publisher
# Macmillan & Co.      85
# London               69
# Privately printed    53
# Longmans & Co.       52
# Hurst & Blackett     51
# Name: count, dtype: int64

# %%
dfA = cleaned_books_df[cleaned_books_df['Publisher'] ==publish_list.index[0]]
filerdf = dfA[(dfA['Date of Publication']>=1800) & (dfA['Date of Publication']<=1900)]
yearly_counts = filerdf.groupby('Date of Publication').size()

yearly_counts.sort_index()
# Out:
# Date of Publication
# 1857     1
# 1859     1
# 1862     1
# 1864     1
# 1869     1
# 1870     1
# 1873     1
# 1874     2
# 1875     1
# 1876     1
# 1880     3
# 1881     1
# 1882     2
# 1883     1
# 1884     4
# 1885     2
# 1886     4
# 1887     2
# 1888     1
# 1889     2
# 1890     3
# 1891     1
# 1892     1
# 1893     5
# 1894     2
# 1895     8
# 1896    16
# 1897     6
# 1898     7
# 1899     3
# dtype: int64

# %%
def filter_topX_publisher_in_1800_1900(n,df):
    #n: Number of target searches
    #df: input dataframe
    #Your code:
    dic_res = {}
    publish_list = cleaned_books_df['Publisher'].value_counts()[:n]
    for publisher in publish_list.index:
        dfA = cleaned_books_df[cleaned_books_df['Publisher'] ==publisher]
        filerdf = dfA[(dfA['Date of Publication']>=1800) & (dfA['Date of Publication']<=1900)]
        yearly_counts = filerdf.groupby('Date of Publication').size()

        sorted_years = yearly_counts.sort_index()

        dic_res[publisher] = sorted_years
        
    return dic_res

filter_topX_publisher_in_1800_1900(5,cleaned_books_df)
# Out:
# {'Macmillan & Co.': Date of Publication
#  1857     1
#  1859     1
#  1862     1
#  1864     1
#  1869     1
#  1870     1
#  1873     1
#  1874     2
#  1875     1
#  1876     1
#  1880     3
#  1881     1
#  1882     2
#  1883     1
#  1884     4
#  1885     2
#  1886     4
#  1887     2
#  1888     1
#  1889     2
#  1890     3
#  1891     1
#  1892     1
#  1893     5
#  1894     2
#  1895     8
#  1896    16
#  1897     6
#  1898     7
#  1899     3
#  dtype: int64,
#  'London': Date of Publication
#  1802    1
#  1803    1
#  1805    1
#  1806    2
#  1807    1
#  1819    1
#  1820    1
#  1845    1
#  1846    1
#  1848    1
#  1850    1
#  1853    1
#  1854    1
#  1858    1
#  1862    1
#  1865    2
#  1866    3
#  1867    1
#  1869    1
#  1871    1
#  1872    1
#  1875    1
#  1880    1
#  1885    1
#  1886    1
#  1888    2
#  1889    1
#  1890    2
#  1891    1
#  1892    1
#  1895    1
#  1896    2
#  1897    2
#  1898    3
#  dtype: int64,
#  'Privately printed': Date of Publication
#  1800    1
#  1804    1
#  1806    1
#  1807    1
#  1823    1
#  1829    1
#  1830    2
#  1835    1
#  1836    1
#  1837    2
#  1843    1
#  1844    1
#  1850    2
#  1852    3
#  1853    1
#  1856    1
#  1859    2
#  1860    1
#  1861    1
#  1866    1
#  1869    1
#  1870    1
#  1871    1
#  1874    1
#  1876    1
#  1877    2
#  1880    3
#  1881    1
#  1882    1
#  1883    2
#  1884    1
#  1886    2
#  1887    1
#  1890    1
#  1895    1
#  1897    1
#  dtype: int64,
#  'Longmans & Co.': Date of Publication
#  1834    1
#  1839    1
#  1864    1
#  1868    1
#  1873    1
#  1876    1
#  1877    1
#  1878    1
#  1882    1
#  1884    1
#  1885    2
#  1886    2
#  1887    3
#  1888    3
#  1889    6
#  1891    2
#  1892    3
#  1893    3
#  1894    4
#  1895    4
#  1896    5
#  1897    4
#  1898    1
#  dtype: int64,
#  'Hurst & Blackett': Date of Publication
#  1853    1
#  1854    1
#  1855    1
#  1856    3
#  1857    1
#  1858    1
#  1859    1
#  1860    3
#  1861    2
#  1862    3
#  1863    3
#  1864    1
#  1865    1
#  1866    2
#  1867    2
#  1869    2
#  1870    2
#  1871    1
#  1875    1
#  1876    1
#  1877    1
#  1878    1
#  1880    3
#  1881    1
#  1882    1
#  1884    1
#  1885    1
#  1888    3
#  1889    1
#  1893    1
#  1897    2
#  1899    1
#  dtype: int64}

# %%
# Extracting publishers, publish years, and publish items
publisher_data_dic = filter_topX_publisher_in_1800_1900(5,cleaned_books_df)

# Creating a line graph
plt.figure(figsize=(10, 6))

for pub,years_data in publisher_data_dic.items():
#     print(pub,years_data)
    plt.plot(years_data.index, years_data, '-', label=pub)

# plt.plot(yearly_publication_counts.index, yearly_publication_counts, color='blue')
plt.title('Year of Publication vs. Number of Publications')
plt.xlabel('Year of Publication')
plt.ylabel('Number of Publications')
# plt.xticks([1500,1550,1600,1650,1700,1750,1800,1850,1900],
#            ['1890','1891','1892','1893','1894','1895','1896','1897','1898',],fontsize = 15)
plt.legend()
plt.grid(axis='y')
plt.show()

# %% [markdown]
# ### Compute the cumulative sum of Publications. (Please watch the tutorial)

# %%
a = np.array([1,2,3,4,5])
np.cumsum(a)
# Out:
# array([ 1,  3,  6, 10, 15])

# %%
# Extracting publishers, publish years, and publish items
publisher_data_dic = filter_topX_publisher_in_1800_1900(5,cleaned_books_df)

# Creating a line graph
plt.figure(figsize=(10, 6))

for pub,years_data in publisher_data_dic.items():
#     print(pub,years_data)
    years_data = np.cumsum(years_data)
    plt.plot(years_data.index, years_data, '-', label=pub)

# plt.plot(yearly_publication_counts.index, yearly_publication_counts, color='blue')
plt.title('Year of Publication vs. Number of Publications')
plt.xlabel('Year of Publication')
plt.ylabel('Number of Publications')
# plt.xticks([1500,1550,1600,1650,1700,1750,1800,1850,1900],
#            ['1890','1891','1892','1893','1894','1895','1896','1897','1898',],fontsize = 15)
plt.legend()
plt.grid(axis='y')
plt.show()
